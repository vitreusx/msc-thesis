# %%
from loaders import *

res_df, scalars = final_dreamerv2_loader()
ref_df = reference_loader()

# %%
dv3_cols = ["Random", "Human", "SimPLe", "CURL", "SPR", "IRIS", "DreamerV3"]

dv3_scores = """
Alien 228 7128 617 711 842 420 959
Amidar 6 1720 74 114 180 143 139
Assault 222 742 527 501 566 1524 706
Asterix 210 8503 1128 567 962 854 932
BankHeist 14 753 34 65 345 53 649
BattleZone 2360 37188 4031 8998 14834 13074 12250
Boxing 0 12 8 1 36 70 78
Breakout 2 30 16 3 20 84 31
ChopperCommand 811 7388 979 784 946 1565 420
CrazyClimber 10780 35829 62584 9154 36700 59324 97190
DemonAttack 152 1971 208 646 518 2034 303
Freeway 0 30 17 28 19 31 0
Frostbite 65 4335 237 1226 1171 259 909
Gopher 258 2412 597 401 661 2236 3730
Hero 1027 30826 2657 4988 5859 7037 11161
Jamesbond 29 303 100 331 366 463 445
Kangaroo 52 3035 51 740 3617 838 4098
Krull 1598 2666 2205 3049 3682 6616 7782
KungFuMaster 258 22736 14862 8156 14783 21760 21420
MsPacman 307 6952 1480 1064 1318 999 1327
Pong –21 15 13 –18 –5 15 18
PrivateEye 25 69571 35 82 86 100 882
Qbert 164 13455 1289 727 866 746 3405
RoadRunner 12 7845 5641 5006 12213 9615 15565
Seaquest 68 42055 683 315 558 661 618
"""

dv3_v2_cols = ["Random", "Human", "PPO", "SimPLe", "SPR", "TWM", "IRIS", "DreamerV3"]

dv3_v2_scores = """
Alien 228 7128 276 617 842 675 420 1118
Amidar 6 1720 26 74 180 122 143 97
Assault 222 742 327 527 566 683 1524 683
Asterix 210 8503 292 1128 962 1117 854 1062
BankHeist 14 753 14 34 345 467 53 398
BattleZone 2360 37188 2233 4031 14834 5068 13074 20300
Boxing 0 12 3 8 36 78 70 82
Breakout 2 30 3 16 20 20 84 10
ChopperCommand 811 7388 1005 979 946 1697 1565 2222
CrazyClimber 10780 35829 14675 62584 36700 71820 59324 86225
DemonAttack 152 1971 160 208 518 350 2034 577
Freeway 0 30 2 17 19 24 31 0
Frostbite 65 4335 127 237 1171 1476 259 3377
Gopher 258 2412 368 597 661 1675 2236 2160
Hero 1027 30826 2596 2657 5859 7254 7037 13354
Jamesbond 29 303 41 100 366 362 463 540
Kangaroo 52 3035 55 51 3617 1240 838 2643
Krull 1598 2666 3222 2205 3682 6349 6616 8171
KungFuMaster 258 22736 2090 14862 14783 24555 21760 25900
MsPacman 307 6952 366 1480 1318 1588 999 1521
Pong -21 15 -20 13 -5 19 15 -4
PrivateEye 25 69571 100 35 86 87 100 3238
Qbert 164 13455 317 1289 866 3331 746 2921
RoadRunner 12 7845 602 5641 12213 9109 9615 19230
Seaquest 68 42055 305 683 558 774 661 962
UpNDown 533 11693 1502 3350 10859 15982 3546 46910
"""

dv3_v2_stats = """
Mean 0 1.00 0.11 0.33 0.62 0.96 1.05 1.25
Median 0 1.00 0.02 0.13 0.40 0.51 0.29 0.49
"""

bbf_cols = [
    "Random",
    "Human",
    "DER",
    "DrQ",
    "SPR",
    "IRIS",
    "SR-SPR",
    "EfficientZero",
    "BBF",
]
bbf_scores = """
Alien 227.8 7127.7 802.3 865.2 841.9 420.0 1107.8 808.5 1173.2
Amidar 5.8 1719.5 125.9 137.8 179.7 143.0 203.4 148.6 244.6
Assault 222.4 742.0 561.5 579.6 565.6 1524.4 1088.9 1263.1 2098.5
Asterix 210.0 8503.3 535.4 763.6 962.5 853.6 903.1 25557.8 3946.1
BankHeist 14.2 753.1 185.5 232.9 345.4 53.1 531.7 351.0 732.9
BattleZone 2360.0 37187.5 8977.0 10165.3 14834.1 13074.0 17671.0 13871.2 24459.8
Boxing 0.1 12.1 -0.3 9.0 35.7 70.1 45.8 52.7 85.8
Breakout 1.7 30.5 9.2 19.8 19.6 83.7 25.5 414.1 370.6
ChopperCommand 811.0 7387.8 925.9 844.6 946.3 1565.0 2362.1 1117.3 7549.3
CrazyClimber 10780.5 35829.4 34508.6 21539.0 36700.5 59324.2 45544.1 83940.2 58431.8
DemonAttack 152.1 1971.0 627.6 1321.5 517.6 2034.4 2814.4 13003.9 13341.4
Freeway 0.0 29.6 20.9 20.3 19.3 31.1 25.4 21.8 25.5
Frostbite 65.2 4334.7 871.0 1014.2 1170.7 259.1 2584.8 296.3 2384.8
Gopher 257.6 2412.5 467.0 621.6 660.6 2236.1 712.4 3260.3 1331.2
Hero 1027.0 30826.4 6226.0 4167.9 5858.6 7037.4 8524.0 9315.9 7818.6
Jamesbond 29.0 302.8 275.7 349.1 366.5 462.7 389.1 517.0 1129.6
Kangaroo 52.0 3035.0 581.7 1088.4 3617.4 838.2 3631.7 724.1 6614.7
Krull 1598.0 2665.5 3256.9 4402.1 3681.6 6616.4 5911.8 5663.3 8223.4
KungFuMaster 258.5 22736.3 6580.1 11467.4 14783.2 21759.8 18649.4 30944.8 18991.7
MsPacman 307.3 6951.6 1187.4 1218.1 1318.4 999.1 1574.1 1281.2 2008.3
Pong -20.7 14.6 -9.7 -9.1 -5.4 14.6 2.9 20.1 16.7
PrivateEye 24.9 69571.3 72.8 3.5 86.0 100.0 97.9 96.7 40.5
Qbert 163.9 13455.0 1773.5 1810.7 866.3 745.7 4044.1 14448.5 4447.1
Roadrunner 11.5 7845.0 11843.4 11211.4 12213.1 9614.6 13463.4 17751.3 33426.8
Seaquest 68.4 42054.7 304.6 352.3 558.1 661.3 819.0 1100.2 1232.5
UpNDown 533.4 11693.2 3075.0 4324.5 10859.2 3546.2 112450.3 17264.2 12101.7
"""

bbf_stats = """
Median 0.000 1.000 0.189 0.313 0.396 0.289 0.685 1.116 0.917
Mean 0.000 1.000 0.350 0.465 0.616 1.046 1.272 1.945 2.247
"""

dv2_scores = res_df.groupby("env")["score"].mean().reset_index()
dv2_scores = dv2_scores.rename(columns={"env": "Environment", "score": "DreamerV2"})
dv2_stats = dv2_scores.merge(ref_df, left_on="Environment", right_on="task")
norm = (dv2_stats["DreamerV2"] - dv2_stats["random"]) / (
    dv2_stats["human_gamer"] - dv2_stats["random"]
)
dv2_stats = pd.DataFrame.from_records(
    [
        {"Statistic": "Median", "DreamerV2": norm.median()},
        {"Statistic": "Mean", "DreamerV2": norm.mean()},
    ]
)

# %%
import pandas as pd
import io

dv3 = pd.read_csv(io.StringIO(dv3_scores), sep=" ", header=None)
dv3.columns = ["Environment", *dv3_cols]
dv3.to_csv("ref_scores/dv3_scores.csv", index=False)

dv3_v2 = pd.read_csv(io.StringIO(dv3_v2_scores), sep=" ", header=None)
dv3_v2.columns = ["Environment", *dv3_v2_cols]
dv3_v2.to_csv("ref_scores/dv3_v2_scores.csv", index=False)

dv3_v2_stats_df = pd.read_csv(io.StringIO(dv3_v2_stats), sep=" ", header=None)
dv3_v2_stats_df.columns = ["Statistic", *dv3_v2_cols]
dv3_v2_stats_df.to_csv("ref_scores/dv3_v2_stats.csv", index=False)

bbf = pd.read_csv(io.StringIO(bbf_scores), sep=" ", header=None)
bbf.columns = ["Environment", *bbf_cols]
bbf.to_csv("ref_scores/bbf_scores.csv", index=False)

bbf_stats_df = pd.read_csv(io.StringIO(bbf_stats), sep=" ", header=None)
bbf_stats_df.columns = ["Statistic", *bbf_cols]
bbf_stats_df.to_csv("ref_scores/bbf_stats.csv", index=False)

dv2_scores.to_csv("ref_scores/dv2_scores.csv", index=False)
dv2_stats.to_csv("ref_scores/dv2_stats.csv", index=False)
